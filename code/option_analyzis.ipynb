# %%
import json

data = json.load(open("C:\coding\SatoshiVault\code\option_snap.json"))

# %%
data
# Out:
# {'jsonrpc': '2.0',
#  'id': 15613,
#  'result': [{'mid_price': None,
#    'estimated_delivery_price': 42810.01,
#    'volume_usd': 0.0,
#    'quote_currency': 'BTC',
#    'creation_timestamp': 1705524673938,
#    'base_currency': 'BTC',
#    'underlying_index': 'BTC-26JAN24',
#    'underlying_price': 43009.33,
#    'volume': 0.0,
#    'interest_rate': 0.0,
#    'price_change': None,
#    'mark_price': 0.1906592,
#    'open_interest': 32.5,
#    'ask_price': 0.286,
#    'bid_price': None,
#    'instrument_name': 'BTC-26JAN24-35000-C',
#    'last': 0.2007,
#    'low': None,
#    'high': None},
#   {'mid_price': None,
#    'estimated_delivery_price': 42810.01,
#    'volume_usd': 0.0,
#    'quote_currency': 'BTC',
#    'creation_timestamp': 1705524673938,
#    'base_currency': 'BTC',
#    'underlying_index': 'BTC-26JAN24',
#    'underlying_price': 43009.33,
#    'volume': 0.0,
#    'interest_rate': 0.0,
#    'price_change': None,
#    'mark_price': 0.02008551,
# ...
