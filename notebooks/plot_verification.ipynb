# %%
import matplotlib.pyplot as plt
import json
import os
import pandas as pd
import json
import numpy as np
import math
import warnings
warnings.filterwarnings("ignore")

data_dir = "sample_data/plots"
plot_files = [f for f in os.listdir(data_dir) if f.endswith('.json')]
num_plots = len(plot_files)

cols = 4  # Number of columns in the subplot grid (2 plots per row)
rows =  rows = math.ceil(num_plots / cols) # Calculate rows needed

base_figsize=(10, 5)

windth = base_figsize[0] * cols
height = base_figsize[1] * rows


fig, axes = plt.subplots(rows, cols, figsize=(windth, height))  # Adjust the layout and size as needed
axes = axes.flatten()
for i, plot_file in enumerate(plot_files):
    if "merged_option_oi" not in plot_file:
        plot_data = json.load(open(os.path.join(data_dir, plot_file), "r"))
        x = [str(x) for x in plot_data['x']]
        y = plot_data['y']
        price = str(plot_data.get("price"))

        try:
            special_bar_index = x.index(price)
        except ValueError:
            special_bar_index = None
            print(f'{price} is not in the list for {plot_file}.')

        ax = axes[i]
        bars = ax.bar(x, y)

        if special_bar_index is not None and "depth" in plot_file:
            bars[special_bar_index].set_color('red')
            # ax.text(x=special_bar_index + 0.2, y=y[special_bar_index] - (max(y) / 30), s='Current price', ha='left', fontsize=8, color='red')

        try:
            min_y = min(y)  if min(y) < 0 else 0
        except:
            min_y = 0
        try:
            max_y = max(y) / 3
        except:
            max_y = 0
        ax.set_ylim(bottom=min_y, top=max_y)
        ax.set_xlabel(plot_data['xlabel'], fontsize=18)
        ax.set_ylabel(plot_data['ylabel'], fontsize=18)
        ax.set_title(plot_data['legend'], fontsize=18)
        ax.set_xticklabels(x, rotation=90, fontsize=8)
    else:
        nested_dict = json.load(open(os.path.join(data_dir, plot_file), "r"))
        plot_data = {price_range: {exp_range: nested_dict[price_range].get(exp_range, 0)
                      for exp_range in nested_dict[next(iter(nested_dict))]} for price_range in nested_dict}
        df = pd.DataFrame(plot_data).T 
        heats = ax.pcolormesh(df.values, cmap='viridis', edgecolors='k', linewidths=2)
        ax.set_xticks(np.arange(len(df.columns)) + 0.5, labels=df.columns)
        ax.set_yticks(np.arange(len(df.index)) + 0.5, labels=df.index)
        ax.set_title('Open Interest by Price and Expiration Ranges')
        ax.set_xlabel('Expiration Range')
        ax.set_ylabel('Price Range')
        
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.subplots_adjust(hspace=1)  # Adjust hspace as needed to reduce space between rows

# Display the plot
plt.show()
# Out:
# 0.0 is not in the list for cdepth_future.json.
# 0.0 is not in the list for cdepth_spot.json.
# 68160.0 is not in the list for depth_bingx_ws_spot_depth_btcusdt.json.
# None is not in the list for liquidations_total_binance_ws_perpetual_inverse_liquidations_btcusdperp.json.
# None is not in the list for liquidations_total_binance_ws_perpetual_linear_liquidations_bulk.json.
# None is not in the list for liquidations_total_bybit_ws_perpetual_inverse_liquidations_btcusd.json.
# None is not in the list for liquidations_total_bybit_ws_perpetual_linear_liquidations_bulk.json.
# None is not in the list for liquidations_total_deribit_ws_future_tradesagg_btc.json.
# None is not in the list for liquidations_total_gateio_ws_perpetual_trades_btcusdt.json.
# None is not in the list for liquidations_total_okx_ws_perpetual_liquidations_bulk.json.
# 0.0 is not in the list for merged_depth_future.json.
# 0.0 is not in the list for merged_depth_spot.json.
# None is not in the list for merged_liquidations_total.json.
# None is not in the list for merged_oideltas.json.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 61
#      59 else:
#      60     nested_dict = json.load(open(os.path.join(data_dir, plot_file), "r"))
# ---> 61     plot_data = {price_range: {exp_range: nested_dict[price_range].get(exp_range, 0)
#      62                   for exp_range in nested_dict[next(iter(nested_dict))]} for price_range in nested_dict}
#      63     df = pd.DataFrame(plot_data).T
#      64     heats = ax.pcolormesh(df.values, cmap='viridis', edgecolors='k', linewidths=2)
#
# Cell In[2], line 61, in <dictcomp>(.0)
#      59 else:
#      60     nested_dict = json.load(open(os.path.join(data_dir, plot_file), "r"))
# ---> 61     plot_data = {price_range: {exp_range: nested_dict[price_range].get(exp_range, 0)
#      62                   for exp_range in nested_dict[next(iter(nested_dict))]} for price_range in nested_dict}
#      63     df = pd.DataFrame(plot_data).T
#      64     heats = ax.pcolormesh(df.values, cmap='viridis', edgecolors='k', linewidths=2)
#
# Cell In[2], line 61, in <dictcomp>(.0)
#      59 else:
#      60     nested_dict = json.load(open(os.path.join(data_dir, plot_file), "r"))
# ---> 61     plot_data = {price_range: {exp_range: nested_dict[price_range].get(exp_range, 0)
#      62                   for exp_range in nested_dict[next(iter(nested_dict))]} for price_range in nested_dict}
#      63     df = pd.DataFrame(plot_data).T
#      64     heats = ax.pcolormesh(df.values, cmap='viridis', edgecolors='k', linewidths=2)
#
# AttributeError: 'str' object has no attribute 'get'

# %%
import time

time.time()
# Out:
# 1718666717.7514946

# %%
1717349032
# Out:
# 1717349032

# %%
1718666717.7514946
1717349032.334
